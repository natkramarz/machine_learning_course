# %% [markdown]
# # Lasso Regression

# %%
'''%pip install numpy
# %pip install pandas
# %pip install matplotlib
# %pip install sklearn '''
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from sklearn import linear_model
import scipy.stats as stats
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn import model_selection

# %% [markdown]
# Rozważmy następujący zbiór punktów:

# %%
true_fun = lambda X: np.cos(1.5 * np.pi * X)
n_samples=20
x = np.sort(np.random.rand(n_samples))
y = true_fun(x) + np.random.randn(n_samples) * 0.1
x=np.vstack(x)

# %% [markdown]
# # Przykład
# Proszę wykonać regresję (Ridge Regression) na powyższym zbiorze danych

# %%
clf = Lasso(alpha=1.0)
clf.fit(x, y) 

x_plot = np.vstack(np.linspace(0, 1, 20))
plt.plot(x_plot, clf.predict(x_plot), color='blue',linewidth=3)
plt.plot(x, y, 'ok');
plt.show()

# %% [markdown]
# ## Regresja liniowa

# %%
# prepare models
models = []
predicts = []
names=[]
models.append(('LR degree 2', make_pipeline(PolynomialFeatures(2), linear_model.LinearRegression()) ))
models.append(('LR degree 20', make_pipeline(PolynomialFeatures(20), linear_model.LinearRegression()) ))

x_plot = np.vstack(np.linspace(-3, 3, 1000))
for name, model in models:
    print(name)
    model.fit(x, y)
    predicts.append(model.predict(x_plot))
    names.append(name)
    
plt.plot(x, y, 'ok');
for i in range(len(models)):
    #print(i)
    plt.plot(x_plot, predicts[i],linewidth=3,label=names[i])
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
plt.legend()    
plt.show()
# Out:
# LR degree 2
# LR degree 20

# %% [markdown]
# # Zadanie
# Proszę wykonać
# * regresję dla wielomianów o stopniu **20**
# * regresję (Lasso Regression) dla wielomianów o stopniu **20** oraz
#    * alpha = 1
#    * alpha = 10 000
#    * alpha = 0.0001

# %%
models = []
models.append(('Linear Regression degree 20', make_pipeline(PolynomialFeatures(20), linear_model.LinearRegression())))
models.append(('Lasso Regression alpha 1', make_pipeline(PolynomialFeatures(20), Lasso(alpha=1))))
models.append(('Lasso Regression alpha 10000', make_pipeline(PolynomialFeatures(20), Lasso(alpha=10_000))))
models.append(('Lasso Regression alpha 0.0001', make_pipeline(PolynomialFeatures(20), Lasso(alpha=0.0001))))

names = []
predicts = []

x_plot = np.vstack(np.linspace(-3, 3, 1000))
for name, model in models:
    model.fit(x, y)
    predicts.append(model.predict(x_plot))
    names.append(name)
    
plt.plot(x, y, 'ok');
for i in range(len(models)):
    plt.plot(x_plot, predicts[i],linewidth=3,label=names[i])
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
plt.legend()    
plt.show()
# Out:
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.580e-03, tolerance: 9.423e-04
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# # Zdanie
# Dobierz optymalny stopień wielomianu oraz parametr alpha.

# %%
seed=123
kfold = model_selection.KFold(n_splits=5, random_state=seed, shuffle=True)

grid = model_selection.GridSearchCV(make_pipeline(PolynomialFeatures(degree=2), Lasso(alpha = 0.1, random_state=seed)),
                param_grid={'polynomialfeatures__degree': [1, 2, 3, 4, 5, 20], 'lasso__alpha': [0.01,0.1,1,10,100,1000,10000]}, 
                cv=kfold, 
                refit=True)
grid.fit(x, y)
grid.best_params_
# Out:
# {'lasso__alpha': 0.01, 'polynomialfeatures__degree': 5}

# %% [markdown]
# # Zdanie
# Dobierz optymalny stopień wielomianu oraz parametr <tt>alpha</tt> za pomocą metody <tt>GridSearchCV</tt> dla danych reklamowych, obejmującym sprzedaż produktów i ich budżet reklamowy w trzech różnych mediach telewizyjnych, radiu, gazetach.
#
# *  policz r_square score.

# %%
import pandas as pd
df_adv = pd.read_csv('Advertising.csv', index_col=0)
X = df_adv[['TV', 'radio','newspaper']]
y = df_adv['sales']
df_adv.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
grid = model_selection.GridSearchCV(make_pipeline(PolynomialFeatures(degree=2), Lasso(alpha = 0.1, random_state=seed)),
                param_grid={'polynomialfeatures__degree': [1, 2, 3, 4, 5, 20], 'lasso__alpha': [0.01,0.1,1,10,100,1000,10000]}, 
                cv=kfold, 
                refit=True)

grid.fit(X, y)
grid.best_params_
# Out:
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.964e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.290e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.930e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.678e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.871e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.944e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.260e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.910e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.547e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.758e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.927e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.257e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.888e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.522e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.701e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.243e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.154e+00, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.318e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.589e+00, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.256e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.101e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.409e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.091e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.882e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.009e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.101e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.408e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.096e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.742e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.924e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.064e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.401e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.076e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.705e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.869e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.344e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.050e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.475e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.082e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.403e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.269e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.450e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.253e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.903e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.167e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.124e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.376e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.130e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.591e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.979e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.028e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.326e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.031e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.470e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.858e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.274e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.930e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.410e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.852e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.353e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.449e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.029e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.444e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.781e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.206e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.257e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.395e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.309e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.327e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.262e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.906e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.134e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.942e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.077e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.742e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.835e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.456e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.010e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.213e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.023e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.848e-01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.793e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.501e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.968e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.711e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.799e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.838e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.576e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.769e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.856e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.585e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.117e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.713e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.466e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.425e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.385e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.533e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.130e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.047e+02, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.302e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.896e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.755e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.690e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.577e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.338e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.372e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.920e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.482e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.461e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.850e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.452e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.263e+02, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.052e+02, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.357e+02, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.121e+02, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.304e+02, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.130e+02, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.504e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.219e+02, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.987e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.177e+02, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.429e+01, tolerance: 4.174e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.815e+01, tolerance: 4.441e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.817e+01, tolerance: 4.534e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.219e+01, tolerance: 4.339e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.962e+01, tolerance: 4.145e-01
#   model = cd_fast.enet_coordinate_descent(
# /home/natalia/podstawy_sztucznej_inteligencji/venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.457e+01, tolerance: 5.417e-01
#   model = cd_fast.enet_coordinate_descent(
# {'lasso__alpha': 0.1, 'polynomialfeatures__degree': 3}

# %%
from sklearn import metrics


metrics.mean_absolute_error(y, grid.predict(X))
# Out:
# 0.32058781112704726
